# %%
a = 2
b = 4
print(a + b)
print(a * b)
# Out:
# 6
# 8

# %%
age = 5
print(age)
# Out:
# 5

# %%
celsius = 36
fahrenheit  = (celsius * 9/5) +32
print(f"{celsius}C is equal to {fahrenheit} F")
# Out:
# 36C is equal to 96.8 F

# %%
mrp = 50
result = ((mrp*1.6)/1.10)/1.13
dis = result*5/100
print(result)
print(dis)
# Out:
# 64.36041834271923
# 3.2180209171359615

# %%
name = "Bipan Gurung"
print(name)
# Out:
# Bipan Gurung

# %%
a = 5
b = 10

print(a > b)
print(a < b)
print(a == b)
print(a != b)

print(a > 3 and b < 20 )
# Out:
# False
# True
# False
# True
# True

# %%
age = 21

if age >= 18:
  print("you are eligible to vote")

else:
  print("you are not eligible to vote")
# Out:
# you are eligible to vote

# %%
age = int(input("Enter age: "))
if age > 18:
  print("you are eligible for vote")
else:
  print("you are not eligible for vote")
# Out:
# you are eligible for vote

# %%
## day -2
